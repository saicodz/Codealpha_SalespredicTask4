# %% [markdown]
# <a href="https://colab.research.google.com/github/saicodz/Salespredic_CodeAlpha/blob/main/Salesprediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **AUTHOR: SAIKUMAR PENKE**

# %% [markdown]
# **DATA SCIENCE INTERNSHIP @CODE ALPHA**

# %% [markdown]
# ### MY GitHub Link
# (https://github.com/saicodz)

# %% [markdown]
# ## **TASK 1**

# %% [markdown]
# # **SALES PREDICITON USING PYTHON**

# %% [markdown]
# **PROBLEM STATEMENT**
# Sales prediction involves forecasting the amount of a product that customers will purchase, taking into account various factors such as advertising expenditure, target audience segmentation, and advertising platform selection.

# %% [markdown]
# **IMPORTING IMPORTANT LIBRARIES**

# %%
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/Advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.head(10)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# 5           6    8.7   48.9       75.0    7.2
# 6           7   57.5   32.8       23.5   11.8
# 7           8  120.2   19.6       11.6   13.2
# 8           9    8.6    2.1        1.0    4.8
# 9          10  199.8    2.6       21.2   10.6

# %%
df.tail(10)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 190         191   39.5   41.1        5.8   10.8
# 191         192   75.5   10.8        6.0    9.9
# 192         193   17.2    4.1       31.6    5.9
# 193         194  166.8   42.0        3.6   19.6
# 194         195  149.7   35.6        6.0   17.3
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df.shape
# Out:
# (200, 5)

# %%
sns.scatterplot(x=df['TV'], y=df['Sales'], color='blue')
plt.show()

# %%
sns.scatterplot(x=df['Radio'], y=df['Sales'], color='red')
plt.show()

# %%
sns.scatterplot(x=df['Newspaper'], y=df['Sales'], color='green')
plt.show()

# %%
sns.lmplot(x='TV', y='Sales', data=df)
sns.lmplot(x='Radio', y='Sales', data=df)
sns.lmplot(x='Newspaper', y='Sales', data=df)

# %%
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.hist(df['TV'], color='purple')
plt.title('TV')



plt.subplot(222)
plt.hist(df['Radio'], color='orange')
plt.title('Radio')



plt.subplot(223)
plt.hist(df['Newspaper'], color='magenta')
plt.title('Newspaper')



plt.subplot(224)
plt.hist(df['Sales'], color='cyan')
plt.title('Sales')

plt.show()

# %%
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='cividis')
plt.title('Correlation of Advertising mediums with Sales')
plt.show()

# %%
X = df[['TV']]
Y = df[['Sales']]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print(X_train)
print(X_test)
print(Y_train)
print(Y_test)
# Out:
#         TV
# 79   116.0
# 197  177.0
# 38    43.1
# 24    62.3
# 122  224.0
# ..     ...
# 106   25.0
# 14   204.1
# 92   217.7
# 179  165.6
# 102  280.2
#
# [160 rows x 1 columns]
#         TV
# 95   163.3
# 15   195.4
# 30   292.9
# 158   11.7
# 128  220.3
# 115   75.1
# 69   216.8
# 170   50.0
# 174  222.4
# 45   175.1
# 66    31.5
# 182   56.2
# 165  234.5
# 78     5.4
# 186  139.5
# 177  170.2
# 56     7.3
# 152  197.6
# 82    75.3
# 68   237.4
# 124  229.5
# 16    67.8
# 148   38.0
# 93   250.9
# 65    69.0
# 60    53.5
# 84   213.5
# 67   139.3
# 125   87.2
# 132    8.4
# 9    199.8
# 18    69.2
# 55   198.9
# 75    16.9
# 150  280.7
# 104  238.2
# 135   48.3
# 137  273.7
# 164  117.2
# 76    27.5
#      Sales
# 79    11.0
# 197   12.8
# 38    10.1
# 24     9.7
# 122   11.6
# ..     ...
# 106    7.2
# 14    19.0
# 92    19.4
# 179   12.6
# 102   14.8
#
# [160 rows x 1 columns]
#      Sales
# 95    16.9
# 15    22.4
# 30    21.4
# 158    7.3
# 128   24.7
# 115   12.6
# ...

# %%
df_1 = LinearRegression()
df_1.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
X_train_prediction = df_1.predict(X_train)
print(X_train_prediction)
# Out:
# [[12.51708754]
#  [15.3554013 ]
#  [ 9.12506995]
#  [10.01844084]
#  [17.54229878]
#  [ 8.89707426]
#  [10.40463763]
#  [13.97346821]
#  [11.98664858]
#  [10.66985711]
#  [10.75826361]
#  [14.95524559]
#  [ 7.52444711]
#  [ 7.48257035]
#  [10.67451009]
#  [13.14058597]
#  [10.53492088]
#  [20.59930229]
#  [ 8.03162121]
#  [16.31391381]
#  [20.34804172]
#  [15.72298619]
#  [12.37284537]
#  [ 8.22704609]
#  [20.64583202]
#  [ 8.02231526]
#  [20.78076825]
#  [ 7.98974445]
#  [13.36858167]
#  [ 8.31079961]
#  [11.79122369]
#  [10.85132307]
#  [15.88584026]
#  [15.3554013 ]
#  [12.96842596]
#  [16.87227062]
#  [13.76873738]
#  [15.72298619]
#  [17.46785121]
#  [18.36587507]
#  [ 7.91994985]
#  [12.72647134]
#  [11.29335554]
#  [16.01147054]
#  [10.63263333]
#  [16.10918298]
#  [11.10723661]
#  [19.53842436]
#  [ 8.95756291]
#  [19.27785785]
#  [ 7.73383092]
#  [16.13244785]
#  [20.9110515 ]
#  [19.4779357 ]
#  [17.10957226]
#  [14.08513957]
#  [13.24760436]
#  [ 9.79509812]
# ...

# %%
print(Y_train)
# Out:
#      Sales
# 79    11.0
# 197   12.8
# 38    10.1
# 24     9.7
# 122   11.6
# ..     ...
# 106    7.2
# 14    19.0
# 92    19.4
# 179   12.6
# 102   14.8
#
# [160 rows x 1 columns]

# %%
X_test_prediction = df_1.predict(X_test)
print(X_test_prediction)
# Out:
# [[14.71794394]
#  [16.2115484 ]
#  [20.74819743]
#  [ 7.66403631]
#  [17.37013877]
#  [10.61402143]
#  [17.2072847 ]
#  [ 9.44612512]
#  [17.46785121]
#  [15.2669948 ]
#  [ 8.58532504]
#  [ 9.73460946]
#  [18.03086098]
#  [ 7.37089899]
#  [13.61053628]
#  [15.03899911]
#  [ 7.45930549]
#  [16.31391381]
#  [10.62332738]
#  [18.16579721]
#  [17.79821232]
#  [10.27435438]
#  [ 8.88776831]
#  [18.79394862]
#  [10.33019006]
#  [ 9.60897918]
#  [17.05373658]
#  [13.60123034]
#  [11.17703121]
#  [ 7.51048819]
#  [16.41627922]
#  [10.339496  ]
#  [16.37440246]
#  [ 7.90599093]
#  [20.18053468]
#  [18.203021  ]
#  [ 9.36702457]
#  [19.85482655]
#  [12.57292322]
#  [ 8.39920611]]

# %%
print(Y_test)
# Out:
#      Sales
# 95    16.9
# 15    22.4
# 30    21.4
# 158    7.3
# 128   24.7
# 115   12.6
# 69    22.3
# 170    8.4
# 174   11.5
# 45    14.9
# 66     9.5
# 182    8.7
# 165   11.9
# 78     5.3
# 186   10.3
# 177   11.7
# 56     5.5
# 152   16.6
# 82    11.3
# 68    18.9
# 124   19.7
# 16    12.5
# 148   10.9
# 93    22.2
# 65     9.3
# 60     8.1
# 84    21.7
# 67    13.4
# 125   10.6
# 132    5.7
# 9     10.6
# 18    11.3
# 55    23.7
# 75     8.7
# 150   16.1
# 104   20.7
# 135   11.6
# 137   20.8
# 164   11.9
# 76     6.9

# %%
df_1.coef_
# Out:
# array([[0.04652973]])

# %%
df_1.intercept_
# Out:
# array([7.11963843])

# %%
0.05473199* 69.2 + 7.14382225
# Out:
# 10.931275958

# %%
plt.scatter(X_test, Y_test)
plt.plot(X_test, 7.14382225 + 0.05473199 * X_test, 'r')
plt.show()

# %%
plt.figure(figsize=(10, 8), facecolor='lightblue', edgecolor='green', alpha=0.5)
plt.scatter(Y_train, X_train_prediction)
plt.xlabel('Original Values')
plt.ylabel('Predicted Values')
plt.title('Original Values vs Predicted Values')
plt.show()

# %%
plt.figure(figsize=(10, 8), facecolor='lightblue', edgecolor='green', alpha=0.5)
plt.scatter(Y_test, X_test_prediction)
plt.xlabel('Original Values')
plt.ylabel('Predicted Values')
plt.title('Original Values vs Predicted Values')
plt.show()

# %% [markdown]
# ## **CONCLUSION**
#
# In conclusion, leveraging machine learning techniques in Python for sales prediction empowers businesses to optimize advertising strategies, maximize sales potential, and make informed decisions based on data-driven insights, ensuring competitive advantage in dynamic markets.
